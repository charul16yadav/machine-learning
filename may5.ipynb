# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread( 'pic anime.jpg' )
img2 = cv2.imread('profile picture.jpg')
img2 = img2[400:1159+400, 350:700+350, :]

# %%
img.shape, img2.shape
# Out:
# ((759, 350, 3), (1159, 700, 3))

# %%
def showing (im):
    plt.imshow(im[:,:,::-1])
    plt.show()



def imshow(im):
    cv2.imshow('preview', im)
    cv2.waitkey(0)
    cv2.destroyAllWindow()

# %%
showing (img) 
showing (img2)

# %%
added = cv2.add(img, img2) 
showing(added)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 added = cv2.add(img, img2)
#       2 showing(added)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
import numpy as np

# %%
img2 = cv2.multiply(img2,1.1* )
# Out:
#   Cell In[20], line 1
#     img2 = cv2.multiply(img2,1.1* )
#                                   ^
# SyntaxError: invalid syntax

# %%
img2_3 = cv2.resize(img2, (400,400), interplotation= cv2. INTER_CUBIC)

# %%
from time import sleep
repeat = True
while repeat:
    for i in range(360):
        i = rotate(img, angle = 1, resize = True)
        cv2.imshow('', i)
        key = cv2.WaitKey(1)
        if key == ord('q'):
        repeat = false
        break
    sleep(0.1)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
#   Cell In[43], line 9
#     repeat = false
#     ^
# IndentationError: expected an indented block after 'if' statement on line 8

# %%
BGR 

img - RGB
img_gray - Gray 
 Red Plane - img[:,:,2]
 Green Plane - img[:,:,1]
 blue plane - img[:,:,0]



im_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
im_b = img[:,:,0].
