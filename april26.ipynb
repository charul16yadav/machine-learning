# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('pic anime.jpg')

# %%
cv2.imshow('i',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (759, 350, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[ 73,  41,  46],
#         [ 73,  41,  46],
#         [ 73,  42,  45],
#         ...,
#         [ 79,  34,  31],
#         [ 82,  34,  33],
#         [ 84,  34,  34]],
#
#        [[ 73,  41,  46],
#         [ 73,  41,  46],
#         [ 73,  42,  45],
#         ...,
#         [ 78,  35,  32],
#         [ 81,  35,  34],
#         [ 84,  36,  35]],
#
#        [[ 73,  41,  46],
#         [ 73,  41,  46],
#         [ 73,  42,  45],
#         ...,
#         [ 77,  36,  34],
#         [ 80,  36,  35],
#         [ 82,  36,  35]],
#
#        ...,
#
#        [[142, 118,  82],
#         [202, 179, 134],
#         [212, 189, 127],
#         ...,
#         [126, 107, 192],
#         [111,  94, 175],
#         [ 98,  82, 160]],
#
#        [[143, 122,  77],
#         [204, 184, 129],
#         [222, 204, 127],
#         ...,
#         [127, 109, 192],
#         [120, 104, 182],
#         [111,  95, 172]],
#
#        [[200, 181, 130],
#         [193, 176, 113],
#         [189, 176,  84],
#         ...,
#         [122, 105, 186],
#         [125, 106, 185],
#         [121, 103, 180]]], dtype=uint8)

# %%
img1 = plt.imread('pic anime.jpg')
plt.imshow(img1)

# %%
img2 =  ski.io.imread('pic anime.jpg')
ski.io.imsave('pi')

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
ski.io.imshow(img_gray,)

# %%
_, img_binary = cv2.threshold(img, 50, 255, cv2.THRESH_BINARY)
cv2.imshow('',img_binary,)
cv2,waitKey(0) 
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 _, img_binary = cv2.threshold(img, 50, 255, cv2.THRESH_BINARY)
#       2 cv2.imshow('',img_binary,)
#       3 cv2,waitKey(0)
#
# NameError: name 'cv2' is not defined

# %%
name = input("what's your name?")
print("hello,")
print(name)
# Out:
# hello,

# %%
open cv as cv2
# Out:
#   Cell In[2], line 1
#     open cv as cv2
#          ^
# SyntaxError: invalid syntax

# %%
vid = cv2.VideoCapture (0)
vid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 vid = cv2.VideoCapture (0)
#       2 vid
#
# NameError: name 'cv2' is not defined
