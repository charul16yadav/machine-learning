# %%
import matplotlib.pyplot as plt
import cv2

# %%
vid = cv2.VideoCapture (0)
vid
# Out:
# < cv2.VideoCapture 00000264EDC06EF0>

# %%
vid.isOpened()
# Out:
# True

# %%
k = vid.read()

# %%
type(k)
# Out:
# tuple

# %%
type(k) , len(k)
# Out:
# (tuple, 2)

# %%
flag, img = vid.read()

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
if flag:
    plt.imshow(img)

# %%
for i in range ( 100 ):
  flag, img = vid.read()
  if flag:
    cv2.imshow('Preview', img)
    cv2.waitKey(1)
    vid.release()
    cv2.destroyAllWindows()
  #  cv2.waitKey(1)

# %%
for i in range ( 100 ):
  flag, img = vid.read()
  if flag:
    cv2.imshow('Preview', img)
    key = cv2waitKey(1)
    if key ==  ord('c'):
        break
    cv2.waitKey(1)
    vid.release()
    cv2.destroyAllWindows()
   # cv2.waitKey(1)

# %%
ord('a')
# Out:
# 97

# %%
from time import sleep

# %%
import cv2

from time import sleep

vid = cv2.VideoCapture (0)


while True :
   flag, img =  vid.read()
   if flag:
     img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


     cv2.imshow('Preview', img)
     key = cv2.waitKey(1)
   if key ==  ord('x'):
        break
   else:
       break  
   sleep(0.1)
      
vid.release()
cv2.destroyAllWindows()

# %%
import cv2
from time import sleep

fd = cv2.CasecadeClassifier(
    cv2.data.haarcascades + ''
)
vid = cv2.VideoCapture (0)

while True:
    flag, image = vid.read() 
    if flag :
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # x1, y1 , w , h=(200,400,300,400)
        faces = fd.detectMultiScale(img_gray,1.1,5)
        for x1,y1,w,h in faces:
          img_cropped = img [y1:y1+h, x1:x1+w, :]

          cv2.rectangle(
            img,
            pt1=(x1,y1), pt2=(x1+w,y1+h),
            color=(0,0,255), thickness=10
          )

        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key ==  ord('x'):
          break
    else:
       break  
    sleep(0.1)
vid.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 import cv2
#       2 from time import sleep
# ----> 4 fd = cv2.CasecadeClassifier(
#       5     cv2.data.haarcascades + ''
#       6 )
#       7 vid = cv2.VideoCapture (0)
#       9 while True:
#
# AttributeError: module 'cv2' has no attribute 'CasecadeClassifier'
